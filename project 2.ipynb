# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\SIDDHARTHA\Downloads\data.csv")
df
# Out:
#              price  bedrooms  bathrooms  sqft_living       city  statezip  \
# 0     2.384000e+06         5       2.50         3650    Seattle  WA 98119
# 1     3.420000e+05         3       2.00         1930       Kent  WA 98042
# 2     4.200000e+05         3       2.25         2000   Bellevue  WA 98008
# 3     5.500000e+05         4       2.50         1940    Redmond  WA 98052
# 4     4.900000e+05         2       1.00          880    Seattle  WA 98115
# ...            ...       ...        ...          ...        ...       ...
# 4594  3.081667e+05         3       1.75         1510    Seattle  WA 98133
# 4595  5.343333e+05         3       2.50         1460   Bellevue  WA 98007
# 4596  4.169042e+05         3       2.50         3010     Renton  WA 98059
# 4597  2.034000e+05         4       2.00         2090    Seattle  WA 98178
# 4598  2.206000e+05         3       2.50         1490  Covington  WA 98042
#
#      country
# 0        USA
# 1        USA
# 2        USA
# 3        USA
# ...

# %%
# To Check Variable/Column data Types
df.dtypes
# Out:
# price          float64
# bedrooms         int64
# bathrooms      float64
# sqft_living      int64
# city            object
# statezip        object
# country         object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4594    False
# 4595    False
# 4596    False
# 4597    False
# 4598    False
# Length: 4599, dtype: bool

# %%
df = df.drop_duplicates()

# %%
# To show column wise total missing values(null)
df.isnull().sum()
# Out:
# price          0
# bedrooms       0
# bathrooms      0
# sqft_living    0
# city           0
# statezip       0
# country        0
# dtype: int64

# %%
# To show column wise total missing values( not null)
df.notnull().sum()
# Out:
# price          4595
# bedrooms       4595
# bathrooms      4595
# sqft_living    4595
# city           4595
# statezip       4595
# country        4595
# dtype: int64

# %%
df = df.dropna()

# %%
# Selecting all rows data with 1st 5 coulmns
df5 = df.iloc[:, 0:5]
df5
# Out:
#              price  bedrooms  bathrooms  sqft_living       city
# 0     2.384000e+06         5       2.50         3650    Seattle
# 1     3.420000e+05         3       2.00         1930       Kent
# 2     4.200000e+05         3       2.25         2000   Bellevue
# 3     5.500000e+05         4       2.50         1940    Redmond
# 4     4.900000e+05         2       1.00          880    Seattle
# ...            ...       ...        ...          ...        ...
# 4594  3.081667e+05         3       1.75         1510    Seattle
# 4595  5.343333e+05         3       2.50         1460   Bellevue
# 4596  4.169042e+05         3       2.50         3010     Renton
# 4597  2.034000e+05         4       2.00         2090    Seattle
# 4598  2.206000e+05         3       2.50         1490  Covington
#
# [4595 rows x 5 columns]

# %%
# Duplicating a dataframe df
df1 = df.copy()
df1
# Out:
#              price  bedrooms  bathrooms  sqft_living       city  statezip  \
# 0     2.384000e+06         5       2.50         3650    Seattle  WA 98119
# 1     3.420000e+05         3       2.00         1930       Kent  WA 98042
# 2     4.200000e+05         3       2.25         2000   Bellevue  WA 98008
# 3     5.500000e+05         4       2.50         1940    Redmond  WA 98052
# 4     4.900000e+05         2       1.00          880    Seattle  WA 98115
# ...            ...       ...        ...          ...        ...       ...
# 4594  3.081667e+05         3       1.75         1510    Seattle  WA 98133
# 4595  5.343333e+05         3       2.50         1460   Bellevue  WA 98007
# 4596  4.169042e+05         3       2.50         3010     Renton  WA 98059
# 4597  2.034000e+05         4       2.00         2090    Seattle  WA 98178
# 4598  2.206000e+05         3       2.50         1490  Covington  WA 98042
#
#      country
# 0        USA
# 1        USA
# 2        USA
# 3        USA
# ...

# %%
# To see discreptive stats of df
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living
# count  4.595000e+03  4595.000000  4595.000000   4595.000000
# mean   5.521411e+05     3.401741     2.161589   2140.390860
# std    5.640906e+05     0.908815     0.783711    963.164914
# min    0.000000e+00     0.000000     0.000000    370.000000
# 25%    3.234167e+05     3.000000     1.750000   1461.500000
# 50%    4.610000e+05     3.000000     2.250000   1980.000000
# 75%    6.550000e+05     4.000000     2.500000   2620.000000
# max    2.659000e+07     9.000000     8.000000  13540.000000

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living      city  statezip country
# 0  2384000.0         5       2.50         3650   Seattle  WA 98119     USA
# 1   342000.0         3       2.00         1930      Kent  WA 98042     USA
# 2   420000.0         3       2.25         2000  Bellevue  WA 98008     USA
# 3   550000.0         4       2.50         1940   Redmond  WA 98052     USA
# 4   490000.0         2       1.00          880   Seattle  WA 98115     USA

# %%
df_city=pd.DataFrame(df.groupby('city')['price'].mean().reset_index())
df_city.head()
# Out:
#                  city          price
# 0              Algona  207288.000000
# 1              Auburn  299340.442765
# 2  Beaux Arts Village  745000.000000
# 3            Bellevue  847180.662995
# 4       Black Diamond  339605.555556

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living      city  statezip country
# 0  2384000.0         5       2.50         3650   Seattle  WA 98119     USA
# 1   342000.0         3       2.00         1930      Kent  WA 98042     USA
# 2   420000.0         3       2.25         2000  Bellevue  WA 98008     USA
# 3   550000.0         4       2.50         1940   Redmond  WA 98052     USA
# 4   490000.0         2       1.00          880   Seattle  WA 98115     USA

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['city_encoded'] = le.fit_transform(df['city'])

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living      city  statezip country  \
# 0  2384000.0         5       2.50         3650   Seattle  WA 98119     USA
# 1   342000.0         3       2.00         1930      Kent  WA 98042     USA
# 2   420000.0         3       2.25         2000  Bellevue  WA 98008     USA
# 3   550000.0         4       2.50         1940   Redmond  WA 98052     USA
# 4   490000.0         2       1.00          880   Seattle  WA 98115     USA
#
#    city_encoded
# 0            35
# 1            18
# 2             3
# 3            31
# 4            35

# %%
df_numeric=df[['price','bedrooms','bathrooms','sqft_living','city_encoded']]
df_numeric.corr()
# Out:
#                  price  bedrooms  bathrooms  sqft_living  city_encoded
# price         1.000000  0.200304   0.327064     0.430374      0.018706
# bedrooms      0.200304  1.000000   0.545893     0.594862     -0.130378
# bathrooms     0.327064  0.545893   1.000000     0.761117     -0.096883
# sqft_living   0.430374  0.594862   0.761117     1.000000     -0.109548
# city_encoded  0.018706 -0.130378  -0.096883    -0.109548      1.000000

# %%
#heatmap

# %%
# assigning X and y and converting to numpy arrays

x = df[['sqft_living']].values
y = df['price'].values

# splitting the data into training and testing data

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

print("x_train:", x_train)
print("y_train:", y_train)
# Out:
# x_train: [[1480]
#  [1630]
#  [1350]
#  ...
#  [ 870]
#  [1580]
#  [2680]]
# y_train: [395000. 360000. 288790. ... 234000. 406000. 320000.]

# %%
from sklearn.linear_model import LinearRegression

# create model
model = LinearRegression()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)

# %%
pd.DataFrame({'actual': y_test, 'predicted': y_pred}).head()
# Out:
#      actual      predicted
# 0  754950.0  668340.801982
# 1  524000.0  280380.249637
# 2  735000.0  723019.806004
# 3  775000.0  650114.467308
# 4  152000.0  272568.963348

# %% [markdown]
# # error metrics

# %%
#calculating mae(mean absolute error)
mae=mean_absolute_error(y_test,y_pred)
print("MAE:",mae)
#calculating mse(mean squarred error)
mse=mean_squared_error(y_test,y_pred)
print("MSE:",mse)
#calculating r2_score
r2=r2_score(y_test,y_pred)
print("R2 Score:",r2)
# Out:
# MAE: 227740.95882083103
# MSE: 1008913843742.2449
# R2 Score: 0.0407465840792004

# %% [markdown]
# # visualisation

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x_train[:,0],y_train,color='blue',label='training data')
plt.plot(x_test[:,0],y_pred,color='red',label='predicted data')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,6))
plt.bar(df_city['city'].head(),df_city['price'].head())
plt.xlabel('city')
plt.ylabel('price')
plt.xticks(rotation=45)
plt.title('city wise mean prices')
# Out:
# Text(0.5, 1.0, 'city wise mean prices')

# %%
plt.figure(figsize=(7,6))

plt.pie(df_city['price'].head(),
        labels=df_city['city'].head(),
        autopct='%1.1f%%',
        startangle=90)

# create donut shape
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('City Wise Mean Prices (Donut Chart)')
plt.show()
